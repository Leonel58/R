# %% [markdown]
# <a href="https://colab.research.google.com/github/Leonel58/R/blob/main/carga%20de%20datos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
RUTA = "/content/br-amazon-devices.xlsx"

# %%
DATASET = pd.read_excel(RUTA,"Sheet1")

# %%
DATASET
# Out:
#                    time  Rank  \
# 0      2020-07-31 00:38   1.0
# 1      2020-07-31 00:38   2.0
# 2      2020-07-31 00:38   3.0
# 3      2020-07-31 00:38   4.0
# 4      2020-07-31 00:38   5.0
# ...                 ...   ...
# 35895  2020-10-01 22:35  46.0
# 35896  2020-10-01 22:35  47.0
# 35897  2020-10-01 22:35  48.0
# 35898  2020-10-01 22:35  49.0
# 35899  2020-10-01 22:35  50.0
#
#                                            Product Names  Stars  Reviews  \
# 0      Echo Dot (3ª Geração): Smart Speaker com Alexa...    NaN      NaN
# 1      Kindle 10a. geração com iluminação embutida  –...    NaN      NaN
# 2         Kindle Paperwhite 32 GB - Agora à prova d´água    NaN      NaN
# 3      Echo Show 5 - Smart Speaker com tela de 5,5" e...    NaN      NaN
# 4          Capa Nupro para Kindle Paperwhite -  Cor Azul    NaN      NaN
# ...                                                  ...    ...      ...
# 35895  Suporte Apoio Stand De Parede Amazon Echo Dot ...    NaN      NaN
# ...

# %%
DATASET.tail(3)
# Out:
#                    time  Rank  \
# 35897  2020-10-01 22:35  48.0
# 35898  2020-10-01 22:35  49.0
# 35899  2020-10-01 22:35  50.0
#
#                                            Product Names  Stars  Reviews  \
# 35897  Carregador de energia de 30W para Amazon Echo ...    5.0      1.0
# 35898          Capa de Couro para Novo Oasis - Cor Preta    4.0     40.0
# 35899  Suporte Apoio Stand De Mesa Amazon Alexa Echo ...    4.0     20.0
#
#        Authors/Company  Edition/Console  Price_std_or_min  Max_prices
# 35897              NaN              NaN              99.0         NaN
# 35898              NaN              NaN               NaN         NaN
# 35899              NaN              NaN              38.9         NaN

# %%
DATASET.head(3)
# Out:
#                time  Rank                                      Product Names  \
# 0  2020-07-31 00:38   1.0  Echo Dot (3ª Geração): Smart Speaker com Alexa...
# 1  2020-07-31 00:38   2.0  Kindle 10a. geração com iluminação embutida  –...
# 2  2020-07-31 00:38   3.0     Kindle Paperwhite 32 GB - Agora à prova d´água
#
#    Stars  Reviews  Authors/Company  Edition/Console  Price_std_or_min  \
# 0    NaN      NaN              NaN              NaN             249.0
# 1    NaN      NaN              NaN              NaN             349.0
# 2    NaN      NaN              NaN              NaN             499.0
#
#    Max_prices
# 0         NaN
# 1         NaN
# 2       649.0

# %%
CABECERA = ["C1","C2","C3","C4","C5","C6","C7","C8","C9"]

# %%
RUTA = "/content/br-amazon-devices.xlsx"
DATASET = pd.read_excel(RUTA,"Sheet1", header=None, names = CABECERA, skiprows = 1)

# %%
DATASET
# Out:
#                      C1    C2  \
# 0      2020-07-31 00:38   1.0
# 1      2020-07-31 00:38   2.0
# 2      2020-07-31 00:38   3.0
# 3      2020-07-31 00:38   4.0
# 4      2020-07-31 00:38   5.0
# ...                 ...   ...
# 35895  2020-10-01 22:35  46.0
# 35896  2020-10-01 22:35  47.0
# 35897  2020-10-01 22:35  48.0
# 35898  2020-10-01 22:35  49.0
# 35899  2020-10-01 22:35  50.0
#
#                                                       C3   C4     C5  C6  C7  \
# 0      Echo Dot (3ª Geração): Smart Speaker com Alexa...  NaN    NaN NaN NaN
# 1      Kindle 10a. geração com iluminação embutida  –...  NaN    NaN NaN NaN
# 2         Kindle Paperwhite 32 GB - Agora à prova d´água  NaN    NaN NaN NaN
# 3      Echo Show 5 - Smart Speaker com tela de 5,5" e...  NaN    NaN NaN NaN
# 4          Capa Nupro para Kindle Paperwhite -  Cor Azul  NaN    NaN NaN NaN
# ...                                                  ...  ...    ...  ..  ..
# ...

# %%
DATASET.shape
# Out:
# (35900, 9)

# %%
RUTA_2 = "/content/br-automotive.xlsx"
DATASET_ = pd.read_excel(RUTA, "Sheet1" )

# %%
DATASET.head()
# Out:
#                time  Rank                                      Product Names  \
# 0  2020-07-31 00:38   1.0  Echo Dot (3ª Geração): Smart Speaker com Alexa...
# 1  2020-07-31 00:38   2.0  Kindle 10a. geração com iluminação embutida  –...
# 2  2020-07-31 00:38   3.0     Kindle Paperwhite 32 GB - Agora à prova d´água
# 3  2020-07-31 00:38   4.0  Echo Show 5 - Smart Speaker com tela de 5,5" e...
# 4  2020-07-31 00:38   5.0      Capa Nupro para Kindle Paperwhite -  Cor Azul
#
#    Stars  Reviews  Authors/Company  Edition/Console  Price_std_or_min  \
# 0    NaN      NaN              NaN              NaN             249.0
# 1    NaN      NaN              NaN              NaN             349.0
# 2    NaN      NaN              NaN              NaN             499.0
# 3    NaN      NaN              NaN              NaN             499.0
# 4    NaN      NaN              NaN              NaN              79.0
#
#    Max_prices
# 0         NaN
# 1         NaN
# 2       649.0
# 3         NaN
# ...

# %%
CABECERA = "A1","A2","A3","A4","A5","A6","A7","A8","A9"

# %%
RUTA_2 = "/content/br-automotive.xlsx"
DATASET_ = pd.read_excel(RUTA_2, "Sheet1", header = None,
                         names = CABECERA, skiprows=1)

# %%
DATASET_.shape
# Out:
# (19700, 9)

# %%
DATASET_.head(2)
# Out:
#                  A1  A2                                       A3  A4  A5  A6  \
# 0  2020-07-31 00:38   1  Militec-1 Condicionador de metais 200ML NaN NaN NaN
# 1  2020-07-31 00:38  10     Caixa Plástica, Com 1 Bandeja Vonder NaN NaN NaN
#
#    A7     A8  A9
# 0 NaN  72.90 NaN
# 1 NaN  24.38 NaN

# %%
DATASET_.loc[A1]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-87-e8ba86637469> in <cell line: 1>()
# ----> 1 DATASET_.loc[A1]
#
# NameError: name 'A1' is not defined

# %%
DATASET_.loc[:,['A1']]
# Out:
#                      A1
# 0      2020-07-31 00:38
# 1      2020-07-31 00:38
# 2      2020-07-31 00:38
# 3      2020-07-31 00:38
# 4      2020-07-31 00:38
# ...                 ...
# 19695  2020-10-01 22:35
# 19696  2020-10-01 22:35
# 19697  2020-10-01 22:35
# 19698  2020-10-01 22:35
# 19699  2020-10-01 22:35
#
# [19700 rows x 1 columns]

# %%
DATASET_.rename(
    columns = { 'A1': 'TIME'})
# Out:
#                    TIME  A2  \
# 0      2020-07-31 00:38   1
# 1      2020-07-31 00:38  10
# 2      2020-07-31 00:38  11
# 3      2020-07-31 00:38  12
# 4      2020-07-31 00:38  13
# ...                 ...  ..
# 19695  2020-10-01 22:35  46
# 19696  2020-10-01 22:35  47
# 19697  2020-10-01 22:35  48
# 19698  2020-10-01 22:35  49
# 19699  2020-10-01 22:35  50
#
#                                                       A3   A4    A5  A6  A7  \
# 0                Militec-1 Condicionador de metais 200ML  NaN   NaN NaN NaN
# 1                   Caixa Plástica, Com 1 Bandeja Vonder  NaN   NaN NaN NaN
# 2      Multilaser Luva Moto Street Tam. Gg Com Protet...  NaN   NaN NaN NaN
# 3                   Wd-40 Spray Produto Multiusos 300 Ml  NaN   NaN NaN NaN
# 4      Jogo Frisos Laterais Slim, Flash Acessórios, C...  NaN   NaN NaN NaN
# ...                                                  ...  ...   ...  ..  ..
# 19695                       Capacete Ebf Motard 56/Preto  4.8   8.0 NaN NaN
# ...

# %%
DATASET_.rename(
    columns = {"A2":"RANK"}
    )
# Out:
#                      A1  RANK  \
# 0      2020-07-31 00:38     1
# 1      2020-07-31 00:38    10
# 2      2020-07-31 00:38    11
# 3      2020-07-31 00:38    12
# 4      2020-07-31 00:38    13
# ...                 ...   ...
# 19695  2020-10-01 22:35    46
# 19696  2020-10-01 22:35    47
# 19697  2020-10-01 22:35    48
# 19698  2020-10-01 22:35    49
# 19699  2020-10-01 22:35    50
#
#                                                       A3   A4    A5  A6  A7  \
# 0                Militec-1 Condicionador de metais 200ML  NaN   NaN NaN NaN
# 1                   Caixa Plástica, Com 1 Bandeja Vonder  NaN   NaN NaN NaN
# 2      Multilaser Luva Moto Street Tam. Gg Com Protet...  NaN   NaN NaN NaN
# 3                   Wd-40 Spray Produto Multiusos 300 Ml  NaN   NaN NaN NaN
# 4      Jogo Frisos Laterais Slim, Flash Acessórios, C...  NaN   NaN NaN NaN
# ...                                                  ...  ...   ...  ..  ..
# ...

# %%
DATASET_.rename(
    columns = { "A1":"TIME", "A2":"RANK","A3":"Product_Names"}
)
# Out:
#                    TIME  RANK  \
# 0      2020-07-31 00:38     1
# 1      2020-07-31 00:38    10
# 2      2020-07-31 00:38    11
# 3      2020-07-31 00:38    12
# 4      2020-07-31 00:38    13
# ...                 ...   ...
# 19695  2020-10-01 22:35    46
# 19696  2020-10-01 22:35    47
# 19697  2020-10-01 22:35    48
# 19698  2020-10-01 22:35    49
# 19699  2020-10-01 22:35    50
#
#                                            Product_Names   A4    A5  A6  A7  \
# 0                Militec-1 Condicionador de metais 200ML  NaN   NaN NaN NaN
# 1                   Caixa Plástica, Com 1 Bandeja Vonder  NaN   NaN NaN NaN
# 2      Multilaser Luva Moto Street Tam. Gg Com Protet...  NaN   NaN NaN NaN
# 3                   Wd-40 Spray Produto Multiusos 300 Ml  NaN   NaN NaN NaN
# 4      Jogo Frisos Laterais Slim, Flash Acessórios, C...  NaN   NaN NaN NaN
# ...                                                  ...  ...   ...  ..  ..
# ...

# %%
DATASET_2 = DATASET_.rename(
    columns = { "A1":"TIME", "A2":"RANK","A3":"Product_Names"}
)

# %%
DATASET_2
# Out:
#                    TIME  RANK  \
# 0      2020-07-31 00:38     1
# 1      2020-07-31 00:38    10
# 2      2020-07-31 00:38    11
# 3      2020-07-31 00:38    12
# 4      2020-07-31 00:38    13
# ...                 ...   ...
# 19695  2020-10-01 22:35    46
# 19696  2020-10-01 22:35    47
# 19697  2020-10-01 22:35    48
# 19698  2020-10-01 22:35    49
# 19699  2020-10-01 22:35    50
#
#                                            Product_Names   A4    A5  A6  A7  \
# 0                Militec-1 Condicionador de metais 200ML  NaN   NaN NaN NaN
# 1                   Caixa Plástica, Com 1 Bandeja Vonder  NaN   NaN NaN NaN
# 2      Multilaser Luva Moto Street Tam. Gg Com Protet...  NaN   NaN NaN NaN
# 3                   Wd-40 Spray Produto Multiusos 300 Ml  NaN   NaN NaN NaN
# 4      Jogo Frisos Laterais Slim, Flash Acessórios, C...  NaN   NaN NaN NaN
# ...                                                  ...  ...   ...  ..  ..
# ...

# %%
DATASET_.head()
# Out:
#                  A1  A2                                                 A3  \
# 0  2020-07-31 00:38   1            Militec-1 Condicionador de metais 200ML
# 1  2020-07-31 00:38  10               Caixa Plástica, Com 1 Bandeja Vonder
# 2  2020-07-31 00:38  11  Multilaser Luva Moto Street Tam. Gg Com Protet...
# 3  2020-07-31 00:38  12               Wd-40 Spray Produto Multiusos 300 Ml
# 4  2020-07-31 00:38  13  Jogo Frisos Laterais Slim, Flash Acessórios, C...
#
#    A4  A5  A6  A7     A8      A9
# 0 NaN NaN NaN NaN  72.90     NaN
# 1 NaN NaN NaN NaN  24.38     NaN
# 2 NaN NaN NaN NaN  51.46     NaN
# 3 NaN NaN NaN NaN  25.64     NaN
# 4 NaN NaN NaN NaN  33.07  247.19

# %%
DATASET_2.head(3)
# Out:
#                TIME  RANK                                      Product_Names  \
# 0  2020-07-31 00:38     1            Militec-1 Condicionador de metais 200ML
# 1  2020-07-31 00:38    10               Caixa Plástica, Com 1 Bandeja Vonder
# 2  2020-07-31 00:38    11  Multilaser Luva Moto Street Tam. Gg Com Protet...
#
#    A4  A5  A6  A7     A8  A9
# 0 NaN NaN NaN NaN  72.90 NaN
# 1 NaN NaN NaN NaN  24.38 NaN
# 2 NaN NaN NaN NaN  51.46 NaN

# %%
DATASET_2.rename(
    columns = {"A4":"STARS","A5":"REVIWS", "A6":"Authors/Company"}




)
# Out:
#                    TIME  RANK  \
# 0      2020-07-31 00:38     1
# 1      2020-07-31 00:38    10
# 2      2020-07-31 00:38    11
# 3      2020-07-31 00:38    12
# 4      2020-07-31 00:38    13
# ...                 ...   ...
# 19695  2020-10-01 22:35    46
# 19696  2020-10-01 22:35    47
# 19697  2020-10-01 22:35    48
# 19698  2020-10-01 22:35    49
# 19699  2020-10-01 22:35    50
#
#                                            Product_Names  STARS  REVIWS  \
# 0                Militec-1 Condicionador de metais 200ML    NaN     NaN
# 1                   Caixa Plástica, Com 1 Bandeja Vonder    NaN     NaN
# 2      Multilaser Luva Moto Street Tam. Gg Com Protet...    NaN     NaN
# 3                   Wd-40 Spray Produto Multiusos 300 Ml    NaN     NaN
# 4      Jogo Frisos Laterais Slim, Flash Acessórios, C...    NaN     NaN
# ...                                                  ...    ...     ...
# 19695                       Capacete Ebf Motard 56/Preto    4.8     8.0
# ...

# %%
DATASET_3 = DATASET_2.rename(
    columns = {"A4":"STARS","A5":"REVIWS", "A6":"Authors/Company"}




)

# %%
DATASET_3.head(2)
# Out:
#                TIME  RANK                            Product_Names  STARS  \
# 0  2020-07-31 00:38     1  Militec-1 Condicionador de metais 200ML    NaN
# 1  2020-07-31 00:38    10     Caixa Plástica, Com 1 Bandeja Vonder    NaN
#
#    REVIWS  Authors/Company  A7     A8  A9
# 0     NaN              NaN NaN  72.90 NaN
# 1     NaN              NaN NaN  24.38 NaN

# %%
DATASET_3.rename(
    columns = {"A7":"Edition/Console"}



)
# Out:
#                    TIME  RANK  \
# 0      2020-07-31 00:38     1
# 1      2020-07-31 00:38    10
# 2      2020-07-31 00:38    11
# 3      2020-07-31 00:38    12
# 4      2020-07-31 00:38    13
# ...                 ...   ...
# 19695  2020-10-01 22:35    46
# 19696  2020-10-01 22:35    47
# 19697  2020-10-01 22:35    48
# 19698  2020-10-01 22:35    49
# 19699  2020-10-01 22:35    50
#
#                                            Product_Names  STARS  REVIWS  \
# 0                Militec-1 Condicionador de metais 200ML    NaN     NaN
# 1                   Caixa Plástica, Com 1 Bandeja Vonder    NaN     NaN
# 2      Multilaser Luva Moto Street Tam. Gg Com Protet...    NaN     NaN
# 3                   Wd-40 Spray Produto Multiusos 300 Ml    NaN     NaN
# 4      Jogo Frisos Laterais Slim, Flash Acessórios, C...    NaN     NaN
# ...                                                  ...    ...     ...
# 19695                       Capacete Ebf Motard 56/Preto    4.8     8.0
# ...

# %%
DATASET_4 = DATASET_3.rename(
    columns = {"A7":"Edition/Console"}



)

# %%
DATASET_4.head(3)
# Out:
#                TIME  RANK                                      Product_Names  \
# 0  2020-07-31 00:38     1            Militec-1 Condicionador de metais 200ML
# 1  2020-07-31 00:38    10               Caixa Plástica, Com 1 Bandeja Vonder
# 2  2020-07-31 00:38    11  Multilaser Luva Moto Street Tam. Gg Com Protet...
#
#    STARS  REVIWS  Authors/Company  Edition/Console     A8  A9
# 0    NaN     NaN              NaN              NaN  72.90 NaN
# 1    NaN     NaN              NaN              NaN  24.38 NaN
# 2    NaN     NaN              NaN              NaN  51.46 NaN

# %%
DATASET_4.rename (
    columns = {"A8":"Price_std_or_min", "A9":"MAX PRICES"}


)
# Out:
#                    TIME  RANK  \
# 0      2020-07-31 00:38     1
# 1      2020-07-31 00:38    10
# 2      2020-07-31 00:38    11
# 3      2020-07-31 00:38    12
# 4      2020-07-31 00:38    13
# ...                 ...   ...
# 19695  2020-10-01 22:35    46
# 19696  2020-10-01 22:35    47
# 19697  2020-10-01 22:35    48
# 19698  2020-10-01 22:35    49
# 19699  2020-10-01 22:35    50
#
#                                            Product_Names  STARS  REVIWS  \
# 0                Militec-1 Condicionador de metais 200ML    NaN     NaN
# 1                   Caixa Plástica, Com 1 Bandeja Vonder    NaN     NaN
# 2      Multilaser Luva Moto Street Tam. Gg Com Protet...    NaN     NaN
# 3                   Wd-40 Spray Produto Multiusos 300 Ml    NaN     NaN
# 4      Jogo Frisos Laterais Slim, Flash Acessórios, C...    NaN     NaN
# ...                                                  ...    ...     ...
# 19695                       Capacete Ebf Motard 56/Preto    4.8     8.0
# ...

# %%
DATASET_5 = DATASET_4.rename (
    columns = {"A8":"Price_std_or_min", "A9":"MAX PRICES"}


)

# %%
DATASET_5.head(2)
# Out:
#                TIME  RANK                            Product_Names  STARS  \
# 0  2020-07-31 00:38     1  Militec-1 Condicionador de metais 200ML    NaN
# 1  2020-07-31 00:38    10     Caixa Plástica, Com 1 Bandeja Vonder    NaN
#
#    REVIWS  Authors/Company  Edition/Console  Price_std_or_min  MAX PRICES
# 0     NaN              NaN              NaN             72.90         NaN
# 1     NaN              NaN              NaN             24.38         NaN

# %%
DATASET_5.head(2)
# Out:
#                TIME  RANK                            Product_Names  STARS  \
# 0  2020-07-31 00:38     1  Militec-1 Condicionador de metais 200ML    NaN
# 1  2020-07-31 00:38    10     Caixa Plástica, Com 1 Bandeja Vonder    NaN
#
#    REVIWS  Authors/Company  Edition/Console  Price_std_or_min  MAX PRICES
# 0     NaN              NaN              NaN             72.90         NaN
# 1     NaN              NaN              NaN             24.38         NaN

# %%
CABECERA_1 = ('course_name', 'instructor', 'course url', 'course image',
       'course description', 'reviews_avg', 'reviews_count', 'course_duration',
       'lectures_count', 'level', 'price_after_discount', 'main_price',
       'course_flag', 'students_count', 'datos faltantes', 'sin nombres',
       'Unnamed: 16', 'sin datos', 'faltantes', 'rechazados')

# %%
URL = "/content/VISUALIZACION_CHURN_MODEL.csv"
MODELO = pd.read_csv(URL, header=None, names = CABECERA_1, skiprows=1)

# %%
MODELO.head(3)
# Out:
#   course_name  instructor  course url course image course description  \
# 0          LA         117         408           No                 No
# 1          IN          65         415           No                 No
# 2          NY         161         415           No                 No
#
#    reviews_avg  reviews_count  course_duration  lectures_count  level  \
# 0            0          184.5               97           31.37  351.6
# 1            0          129.1              137           21.95  228.5
# 2            0          332.9               67           56.59  317.8
#
#    price_after_discount  main_price  course_flag  students_count  \
# 0                    80       29.89        215.8              90
# 1                    83       19.42        208.8             111
# 2                    97       27.01        160.6             128
#
#    datos faltantes  sin nombres  Unnamed: 16  sin datos  faltantes  rechazados
# ...

# %%
MODELO.shape
# Out:
# (667, 20)

# %%
MODELO.describe()
# Out:
#        instructor  course url  reviews_avg  reviews_count  course_duration  \
# count  667.000000  667.000000   667.000000     667.000000       667.000000
# mean   102.841079  436.157421     8.407796     180.948126       100.937031
# std     40.819480   41.783305    13.994480      55.508628        20.396790
# min      1.000000  408.000000     0.000000      25.900000        30.000000
# 25%     76.000000  408.000000     0.000000     146.250000        87.500000
# 50%    102.000000  415.000000     0.000000     178.300000       101.000000
# 75%    128.000000  415.000000    20.000000     220.700000       115.000000
# max    232.000000  510.000000    51.000000     334.300000       165.000000
#
#        lectures_count       level  price_after_discount  main_price  \
# count      667.000000  667.000000            667.000000  667.000000
# mean        30.761769  203.355322            100.476762   17.285262
# std          9.436463   49.719268             18.948262    4.226160
# ...

# %%
MODELO.rename(
    columns = {"instructor" : "nombre del maestro"})
# Out:
#     course_name  nombre del maestro  course url course image  \
# 0            LA                 117         408           No
# 1            IN                  65         415           No
# 2            NY                 161         415           No
# 3            SC                 111         415           No
# 4            HI                  49         510           No
# ..          ...                 ...         ...          ...
# 662          WI                 114         415           No
# 663          AL                 106         408           No
# 664          VT                  60         415           No
# 665          WV                 159         415           No
# 666          CT                 184         510          Yes
#
#     course description  reviews_avg  reviews_count  course_duration  \
# 0                   No            0          184.5               97
# 1                   No            0          129.1              137
# ...

# %%
MODELO_1 = MODELO.rename(
    columns = {"instructor" : "nombre del maestro"})

# %%
MODELO_1.head(2)
# Out:
#   course_name  nombre del maestro  course url course image course description  \
# 0          LA                 117         408           No                 No
# 1          IN                  65         415           No                 No
#
#    reviews_avg  reviews_count  course_duration  lectures_count  level  \
# 0            0          184.5               97           31.37  351.6
# 1            0          129.1              137           21.95  228.5
#
#    price_after_discount  main_price  course_flag  students_count  \
# 0                    80       29.89        215.8              90
# 1                    83       19.42        208.8             111
#
#    datos faltantes  sin nombres  Unnamed: 16  sin datos  faltantes  rechazados
# 0             9.71          8.7            4       2.35          1       False
# 1             9.40         12.7            6       3.43          4        True

# %%
MODELO.rename(
    columns=
    { "course_name":"NOMBRE DEL CURSO"}

)
# Out:
#     NOMBRE DEL CURSO  instructor  course url course image course description  \
# 0                 LA         117         408           No                 No
# 1                 IN          65         415           No                 No
# 2                 NY         161         415           No                 No
# 3                 SC         111         415           No                 No
# 4                 HI          49         510           No                 No
# ..               ...         ...         ...          ...                ...
# 662               WI         114         415           No                Yes
# 663               AL         106         408           No                Yes
# 664               VT          60         415           No                 No
# 665               WV         159         415           No                 No
# 666               CT         184         510          Yes                 No
#
# ...

# %%
MODELO_2 = MODELO.rename(
    columns=
    { "course_name":"NOMBRE DEL CURSO"}

)

# %%
MODELO_2.head(3)
# Out:
#   NOMBRE DEL CURSO  instructor  course url course image course description  \
# 0               LA         117         408           No                 No
# 1               IN          65         415           No                 No
# 2               NY         161         415           No                 No
#
#    reviews_avg  reviews_count  course_duration  lectures_count  level  \
# 0            0          184.5               97           31.37  351.6
# 1            0          129.1              137           21.95  228.5
# 2            0          332.9               67           56.59  317.8
#
#    price_after_discount  main_price  course_flag  students_count  \
# 0                    80       29.89        215.8              90
# 1                    83       19.42        208.8             111
# 2                    97       27.01        160.6             128
#
#    datos faltantes  sin nombres  Unnamed: 16  sin datos  faltantes  rechazados
# ...

# %%
MODELO_2.shape
# Out:
# (667, 20)

# %%
MODELO_2.rename(
    columns =  {"instructor":"INSTRUCTOR","course":"curso", "url":"URL DE CURSO","course image":"LOGO DEL CURSO",
                "course description":"DESCRIPCION DEL CURSO",
                "reviews_avg":"VISTA AVERAGE",	"reviews_count":"CONTEO DE LAS VISITAS",
                "course_duration":"DURACION DEL CURSO","lectures_count":"CONTEO DE LECTURA",
                "level":"price_after_discount","PRECION" :"DESPUES",
                "main_price":"PRECIO","TIME":"TIEMPO","RANK":"RANKING","Product_Names":"NOMBRE DEL PRODUCTO",
                "STARS":"INICIO","REVIWS":"VISITAS","Authors/Company":"COMPAÑIA" }



)
# Out:
#     NOMBRE DEL CURSO  INSTRUCTOR  course url LOGO DEL CURSO  \
# 0                 LA         117         408             No
# 1                 IN          65         415             No
# 2                 NY         161         415             No
# 3                 SC         111         415             No
# 4                 HI          49         510             No
# ..               ...         ...         ...            ...
# 662               WI         114         415             No
# 663               AL         106         408             No
# 664               VT          60         415             No
# 665               WV         159         415             No
# 666               CT         184         510            Yes
#
#     DESCRIPCION DEL CURSO  VISTA AVERAGE  CONTEO DE LAS VISITAS  \
# 0                      No              0                  184.5
# 1                      No              0                  129.1
# ...

# %%
MODELO_2 = MODELO_2.rename(
    columns =  {"instructor":"INSTRUCTOR","course":"curso", "url":"URL DE CURSO","course image":"LOGO DEL CURSO",
                "course description":"DESCRIPCION DEL CURSO",
                "reviews_avg":"VISTA AVERAGE",	"reviews_count":"CONTEO DE LAS VISITAS",
                "course_duration":"DURACION DEL CURSO","lectures_count":"CONTEO DE LECTURA",
                "level":"price_after_discount","PRECION" :"DESPUES",
                "main_price":"PRECIO","TIME":"TIEMPO","RANK":"RANKING","Product_Names":"NOMBRE DEL PRODUCTO",
                "STARS":"INICIO","REVIWS":"VISITAS","Authors/Company":"COMPAÑIA" }



)

# %%
MODELO_2.head(2)
# Out:
#   NOMBRE DEL CURSO  INSTRUCTOR  course url LOGO DEL CURSO  \
# 0               LA         117         408             No
# 1               IN          65         415             No
#
#   DESCRIPCION DEL CURSO  VISTA AVERAGE  CONTEO DE LAS VISITAS  \
# 0                    No              0                  184.5
# 1                    No              0                  129.1
#
#    DURACION DEL CURSO  CONTEO DE LECTURA  price_after_discount  \
# 0                  97              31.37                 351.6
# 1                 137              21.95                 228.5
#
#    price_after_discount  PRECIO  course_flag  students_count  datos faltantes  \
# 0                    80   29.89        215.8              90             9.71
# 1                    83   19.42        208.8             111             9.40
#
#    sin nombres  Unnamed: 16  sin datos  faltantes  rechazados
# 0          8.7            4       2.35          1       False
# ...

# %%
MODELO_2.rename(
    columns= {"LOGO DEL CURSO" : "LOGO","DESCRIPCION DEL CURSO ":"DESCRIPCION", "NOMBRE DEL CURSO":"CURSO",
              "course url": "URL","DESCRIPCION DEL CURSO":"DESCRIPCION","VISTA AVERAGE":"AVERAGE",
              "CONTEO DE LAS VISITAS":"VISITAS", "DURACION DEL CURSO":"DURACION", "CONTEO DE LECTURA":"LECTURA",
              "price_after_discount":"DISCONTINUADO", "course_flag" :"COURSE", "students_count":"ESTUDIANTES"

    }


)
# Out:
#     CURSO  INSTRUCTOR  URL LOGO DESCRIPCION  AVERAGE  VISITAS  DURACION  \
# 0      LA         117  408   No          No        0    184.5        97
# 1      IN          65  415   No          No        0    129.1       137
# 2      NY         161  415   No          No        0    332.9        67
# 3      SC         111  415   No          No        0    110.4       103
# 4      HI          49  510   No          No        0    119.3       117
# ..    ...         ...  ...  ...         ...      ...      ...       ...
# 662    WI         114  415   No         Yes       26    137.1        88
# 663    AL         106  408   No         Yes       29     83.6       131
# 664    VT          60  415   No          No        0    193.9       118
# 665    WV         159  415   No          No        0    169.8       114
# 666    CT         184  510  Yes          No        0    213.8       105
#
#      LECTURA  DISCONTINUADO  DISCONTINUADO  PRECIO  COURSE  ESTUDIANTES  \
# ...

# %%
MODELO_3 = MODELO_2.rename(
    columns= {"LOGO DEL CURSO" : "LOGO","DESCRIPCION DEL CURSO ":"DESCRIPCION", "NOMBRE DEL CURSO":"CURSO",
              "course url": "URL","DESCRIPCION DEL CURSO":"DESCRIPCION","VISTA AVERAGE":"AVERAGE",
              "CONTEO DE LAS VISITAS":"VISITAS", "DURACION DEL CURSO":"DURACION", "CONTEO DE LECTURA":"LECTURA",
              "price_after_discount":"DISCONTINUADO", "course_flag" :"COURSE", "students_count":"ESTUDIANTES"

    }


)

# %%
MODELO_3.head(2)
# Out:
#   CURSO  INSTRUCTOR  URL LOGO DESCRIPCION  AVERAGE  VISITAS  DURACION  \
# 0    LA         117  408   No          No        0    184.5        97
# 1    IN          65  415   No          No        0    129.1       137
#
#    LECTURA  DISCONTINUADO  DISCONTINUADO  PRECIO  COURSE  ESTUDIANTES  \
# 0    31.37          351.6             80   29.89   215.8           90
# 1    21.95          228.5             83   19.42   208.8          111
#
#    datos faltantes  sin nombres  Unnamed: 16  sin datos  faltantes  rechazados
# 0             9.71          8.7            4       2.35          1       False
# 1             9.40         12.7            6       3.43          4        True

# %%
MODELO_3.loc[25:30,["CURSO"]]
# Out:
#    CURSO
# 25    LA
# 26    NE
# 27    OH
# 28    MO
# 29    AL
# 30    NH

# %%
import pandas as pd

# %%
# Out:
# <ipython-input-220-bff9610b0f50>:2: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   CHURN = pd.read_csv(RUTA_3, sep = '||' )
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# <ipython-input-220-bff9610b0f50> in <cell line: 2>()
#       1 RUTA_3 = ("/content/mx-software.csv")
# ----> 2 CHURN = pd.read_csv(RUTA_3, sep = '||' )
#       3
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     209                 else:
#     210                     kwargs[new_arg_name] = new_arg_value
# --> 211             return func(*args, **kwargs)
#     212
#     213         return cast(F, wrapper)
#
# ...

# %%
RUTA_3
# Out:
# '/content/mx-software.csv'

# %%
RUTA_3.columns
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-219-f1a30792d69b> in <cell line: 1>()
# ----> 1 RUTA_3.columns
#
# AttributeError: 'str' object has no attribute 'columns'
